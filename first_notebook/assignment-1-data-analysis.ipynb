# %%
import datetime
import socket

local_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
computer_id = socket.gethostname()
print('Assignment 1: Solutions by Saima') 
print('Local Time:', local_time)
print('Computer ID:', computer_id)

# %%
import pandas as pd 
import numpy as np
import geopandas as gpd
import seaborn as sb 
import matplotlib.pyplot as plt 

shapefile_path = 'C:\RM_shapefile\RuralMunicipality.shp'
gdf_rm = gpd.read_file(shapefile_path)
df1=pd.read_csv(r'C:\df_1.csv')
df1.dropna(subset=['RM'], inplace=True)
df1['RM'] = df1['RM'].str.capitalize().str.strip()
unique_rms = df1['RM'].unique()

# %%
gdf_rm_yield[gdf_rm_yield['Year']==2021]\
    .plot(column='Canola',
             cmap='Greens',
             legend=True)
plt.title('Canola Yield 2021', color='teal', size=16)
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 gdf_rm_yield[gdf_rm_yield['Year']==2021]\
#       2     .plot(column='Canola',
#       3              cmap='Greens',
#       4              legend=True)
#       5 plt.title('Canola Yield 2021', color='teal', size=16)
#       6 plt.xticks(color='white')
#
# NameError: name 'gdf_rm_yield' is not defined

# %%
df_major_crops=df_rm_yields[['Year', 'RM', 'Canola', 'Spring Wheat',
       'Durum','Oats', 'Lentils', 'Peas', 'Barley']]
df_major_crops.describe().T
# Out:
#                 count         mean         std     min     25%     50%  \
# Year          25607.0  1980.379310   24.799668  1938.0  1959.0  1980.0
# RM            25607.0   248.919280  148.815798     1.0   124.0   247.0
# Canola        14588.0    24.564054    9.603160     0.0    18.0    23.1
# Spring Wheat  25498.0    26.196668   11.631959     0.0    19.0    26.0
# Durum         11926.0    29.200370   10.113954     0.0    23.0    28.3
# Oats          24348.0    47.675041   22.555618     0.0    33.0    46.2
# Lentils        5907.0  1178.983977  417.398358    46.0   900.0  1170.0
# Peas           8703.0    31.240917   10.474982     0.0    24.3    31.2
# Barley        25272.0    38.470558   17.057229     0.0    26.4    38.0
#
#                  75%      max
# Year          2002.0  2023.00
# RM             370.0   622.00
# Canola          30.0    60.10
# Spring Wheat    32.0   198.00
# Durum           34.5    88.10
# Oats            60.0   165.10
# Lentils       1446.0  3411.00
# Peas            38.3    86.80
# Barley          49.1   105.94

# %%
import pandas as pd
df1 = pd.read_csv('df_1.csv')
df2 = pd.read_csv('df_2.csv')
df1['RM'] = df1['RM'].str.capitalize().str.strip()
df2['RM'] = df2['RM'].str.capitalize().str.strip()
df_final = pd.concat([df1,df2]).drop_duplicates().reset_index(drop=True)
print(df_final.sort_values(by=['RM']))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 2
#       1 import pandas as pd
# ----> 2 df1 = pd.read_csv('df_1.csv')
#       3 df2 = pd.read_csv('df_2.csv')
#       4 df1['RM'] = df1['RM'].str.capitalize().str.strip()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'df_1.csv'

# %%
arr = np.array([1, 2, 3, 4], 
ndmin
=2)
